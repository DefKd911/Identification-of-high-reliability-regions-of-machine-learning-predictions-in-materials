# %%
import os

# %%
import pandas as pd

# %%
os.chdir('C:\\Users\\HP\\OneDrive\\Desktop\\Identification of high-reliability regions of machine learning predictions in materials\\Datasets')

# %%
list=os.listdir()

# %%
list
# Out:
# ['ci3c01684_si_002.txt',
#  'ci3c01684_si_003.txt',
#  'ci3c01684_si_004.txt',
#  'ci3c01684_si_005.txt',
#  'ci3c01684_si_006.txt']

# %%
df1=pd.read_csv('ci3c01684_si_002.txt')

# %%
df1
# Out:
#         id  spacegroup  number_of_total_atoms  percent_atom_al  \
# 0        1          33                   80.0           0.6250
# 1        2         194                   80.0           0.6250
# 2        3         227                   40.0           0.8125
# 3        4         167                   30.0           0.7500
# 4        5         194                   80.0           0.0000
# ...    ...         ...                    ...              ...
# 2395  2396          33                   40.0           0.7500
# 2396  2397         167                   30.0           0.4167
# 2397  2398         206                   80.0           0.4375
# 2398  2399          33                   80.0           0.3125
# 2399  2400         206                   80.0           0.8750
#
#       percent_atom_ga  percent_atom_in  lattice_vector_1_ang  \
# 0              0.3750           0.0000                9.9523
# 1              0.3750           0.0000                6.1840
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400 entries, 0 to 2399
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          2400 non-null   int64
#  1   spacegroup                  2400 non-null   int64
#  2   number_of_total_atoms       2400 non-null   float64
#  3   percent_atom_al             2400 non-null   float64
#  4   percent_atom_ga             2400 non-null   float64
#  5   percent_atom_in             2400 non-null   float64
#  6   lattice_vector_1_ang        2400 non-null   float64
#  7   lattice_vector_2_ang        2400 non-null   float64
#  8   lattice_vector_3_ang        2400 non-null   float64
#  9   lattice_angle_alpha_degree  2400 non-null   float64
#  10  lattice_angle_beta_degree   2400 non-null   float64
#  11  lattice_angle_gamma_degree  2400 non-null   float64
#  12  Ef                          2400 non-null   float64
# ...

# %%
df1.isnull().sum()
# Out:
# id                            0
# spacegroup                    0
# number_of_total_atoms         0
# percent_atom_al               0
# percent_atom_ga               0
# percent_atom_in               0
# lattice_vector_1_ang          0
# lattice_vector_2_ang          0
# lattice_vector_3_ang          0
# lattice_angle_alpha_degree    0
# lattice_angle_beta_degree     0
# lattice_angle_gamma_degree    0
# Ef                            0
# Eg                            0
# dtype: int64

# %%
df2=pd.read_csv('ci3c01684_si_003.txt')

# %%
df2
# Out:
#       id  spacegroup  number_of_total_atoms  percent_atom_al  percent_atom_ga  \
# 0      1          33                   80.0           0.1875           0.4688
# 1      2          33                   80.0           0.7500           0.2500
# 2      3         167                   30.0           0.6667           0.1667
# 3      4          12                   80.0           0.5625           0.4375
# 4      5          12                   80.0           0.1875           0.5000
# ..   ...         ...                    ...              ...              ...
# 595  596          12                   80.0           0.0000           0.5938
# 596  597          33                   40.0           0.1250           0.0000
# 597  598         194                   80.0           0.0000           0.2500
# 598  599          33                   40.0           0.6250           0.0000
# 599  600         206                   80.0           0.3750           0.3438
#
# ...

# %%
df3=pd.read_csv('ci3c01684_si_004.txt')

# %%
df3
# Out:
#     Material compositions 1 Material compositions 2  Enorm (eV)  E_raw  (eV)  \
# 0                        Ag                      Ag    0.000000     1.824450
# 1                        Ag                      Co   -0.090142     1.734308
# 2                        Ag                      Cr    0.259139     2.083589
# 3                        Ag                      Cu   -0.022200     1.802250
# 4                        Ag                      Fe    0.317672     2.142122
# ..                      ...                     ...         ...          ...
# 403                      Zr                      Nb   -0.067020     2.576100
# 404                      Zr                      Ta    0.153850     2.796970
# 405                      Zr                      Ti    0.248110     2.891230
# 406                      Zr                      Hf    0.204140     2.847260
# 407                      Zr                      Sn    0.248040     2.891160
#
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 29 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Material compositions 1           408 non-null    object
#  1   Material compositions 2           408 non-null    object
#  2   Enorm (eV)                        408 non-null    float64
#  3   E_raw  (eV)                       408 non-null    float64
#  4   Site2_MeltingT                    408 non-null    float64
#  5   Site1_MendeleevNumber             408 non-null    float64
#  6   Site1_MiracleRadius               408 non-null    float64
#  7   GSestFCClatcnt_max_value          408 non-null    float64
#  8   Site2_BCCenergy_pa                408 non-null    float64
#  9   Site1_BCCfermi                    408 non-null    float64
#  10  CovalentRadius_max_value          408 non-null    float64
# ...

# %%
df4=pd.read_csv('ci3c01684_si_005.txt')

# %%
df4
# Out:
#         formula  z_mean      z_std  grp_mean   grp_std  row_mean   row_std  \
# 0       LaSiAs3    34.0  13.652839      12.4  4.715930       4.6  1.743560
# 1       CsAuBr3    47.8  17.417233      12.6  6.248200       4.8  0.979796
# 2       RbAuBr3    44.2  17.417233      12.6  6.248200       4.6  0.800000
# 3       CsCaBr3    36.0  11.135529      10.8  7.600000       4.4  0.800000
# 4        KCaBr3    28.8   7.600000      10.8  7.600000       4.0  0.000000
# ...         ...     ...        ...       ...       ...       ...       ...
# 1448   Y2NiRuO6    19.8  14.918445      12.0  5.272571       3.1  1.374773
# 1449  Yb2MgTiO6    22.2  24.256133      13.4  5.219195       3.5  2.334524
# 1450   Zn2BiPO6    20.6  22.481993      15.0  1.549193       2.9  1.300000
# 1451  In2GaBiS6    30.8  21.683173      15.0  1.341641       3.8  1.077033
# 1452  Yb2PrDyS6    36.1  24.780839      14.5  3.383785       5.0  2.449490
#
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 61 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   formula            1453 non-null   object
#  1   z_mean             1453 non-null   float64
#  2   z_std              1453 non-null   float64
#  3   grp_mean           1453 non-null   float64
#  4   grp_std            1453 non-null   float64
#  5   row_mean           1453 non-null   float64
#  6   row_std            1453 non-null   float64
#  7   x_mean             1453 non-null   float64
#  8   x_std              1453 non-null   float64
#  9   av_ionrad_mean     1453 non-null   float64
#  10  av_ionrad_std      1453 non-null   float64
#  11  atom_rad_mean      1453 non-null   float64
#  12  atom_rad_std       1453 non-null   float64
#  13  atom_mass_mean     1453 non-null   float64
#  14  atom_mass_std      1453 non-null   float64
# ...

# %%
df5=pd.read_csv('ci3c01684_si_006.txt',sep='\s+')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\HP\AppData\Local\Temp\ipykernel_29676\1721648137.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df5=pd.read_csv('ci3c01684_si_006.txt',sep='\s+')

# %%
df5
# Out:
#      composition  OQMD_Id A_atom B_atom  OQMD_unrelaxed_lattice_parameter  \
# 0          Ac2O3   692323     Ac     Ac                          5.124096
# 1         AcAgO3   351356     Ac     Ag                          4.851243
# 2         AcAgO3   352371     Ag     Ac                          4.851243
# 3         AcAlO3   350231     Ac     Al                          4.844849
# 4         AcAlO3   352192     Al     Ac                          4.844849
# ...          ...      ...    ...    ...                               ...
# 5245       ZrVO3   352914      V     Zr                          4.591791
# 5246       ZrWO3   351166     Zr      W                          4.623399
# 5247       ZrWO3   352893      W     Zr                          4.623399
# 5248      ZrZnO3   352906     Zn     Zr                          4.613397
# 5249      ZrZnO3   354373     Zr     Zn                          4.613397
#
#       OQMD_relaxed_lattice_parameter
# 0                           4.705369
# ...

# %%
df1
# Out:
#         id  spacegroup  number_of_total_atoms  percent_atom_al  \
# 0        1          33                   80.0           0.6250
# 1        2         194                   80.0           0.6250
# 2        3         227                   40.0           0.8125
# 3        4         167                   30.0           0.7500
# 4        5         194                   80.0           0.0000
# ...    ...         ...                    ...              ...
# 2395  2396          33                   40.0           0.7500
# 2396  2397         167                   30.0           0.4167
# 2397  2398         206                   80.0           0.4375
# 2398  2399          33                   80.0           0.3125
# 2399  2400         206                   80.0           0.8750
#
#       percent_atom_ga  percent_atom_in  lattice_vector_1_ang  \
# 0              0.3750           0.0000                9.9523
# 1              0.3750           0.0000                6.1840
# ...
